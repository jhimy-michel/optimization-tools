# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import numpy as np

""" ONLY WORKS FOR 2D GRAPH """
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']
A = np.array([
    [-1, 2],
    [-5, 1],
    [-4, -1]
])


b = np.array([
    [4],
    [-16],
    [-11]
])
spacing = 0.5  # This can be your user specified spacing.
minorLocator = MultipleLocator(spacing)
x1 = np.linspace(-10, 10, 100)
plt.figure(figsize=(11, 9))

for i in range(len(A)):

    if A[i][0] != 0 and A[i][1] != 0:
        div = A[i][1]
        x2 = (x1 * A[i][0] + b[i][0])/div
        # print(x2)
        plt.plot(x1, x2, colors[i], label='({0}) x1 * {1} + x2 * {2} <= {3}'.format(
            i+1, A[i][0], div, b[i][0]), linewidth=2.0)
        plt.fill_between(x1, x2, where=x2 <= (
            x1 * A[i][0] + b[i][0])/div, interpolate=True, color=colors[i], alpha=0.1)
        # continue
    # validate if is a horizontal line
    if A[i][0] == 0 and A[i][1] != 0:
        x2 = b[i][0]/A[i][1]
        plt.axhline(x2, -5, 5, c=colors[i], label='({0}) x2 * {1} <= {2}'.format(
            i+1, A[i][1], b[i][0]))
        #plt.fill_between(
        #    x1, x2, where=x2 <= b[i][0]/A[i][1], interpolate=True, color=colors[i], alpha=0.1)

    # validate if is a vertical line
    if A[i][0] != 0 and A[i][1] == 0:
        x2 = b[i][0]/A[i][0]
        print(x2)
        data_x = np.linspace(-5, 5, 100)
        # print(data_x)
        plt.axvline(x2, -5, 5, c=colors[i], label='({0}) x1 * {1} <= {2}'.format(
            i+1, A[i][0], b[i][0]))
        #plt.fill_between(
        #    x1, x2, 0, where=x1 <= b[i][0]/A[i][0], interpolate=True, color=colors[i], alpha=0.1)


plt.title('Graph')
plt.xlabel('x1', color='#1C2833')
plt.ylabel('x2', color='#1C2833')
plt.ylim(-10, 10)
plt.legend(loc='upper left')

plt.grid(visible=True, which='major', color='k', linestyle='-', alpha=0.2)
plt.grid(visible=True, which='minor', color='r', linestyle='-', alpha=0.2)

plt.minorticks_on()

plt.grid(True)
plt.show()
print(len(x1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/jmichel/Documents/master/Master_James/Master3th/Optimization/optimization-tools/Part1/SimplexMethod/plotMatrix.ipynb Cell 1' in <cell line: 24>()
#      <a href='vscode-notebook-cell:/home/jmichel/Documents/master/Master_James/Master3th/Optimization/optimization-tools/Part1/SimplexMethod/plotMatrix.ipynb#ch0000000?line=36'>37</a>     x2 = b[i][0]/A[i][1]
#      <a href='vscode-notebook-cell:/home/jmichel/Documents/master/Master_James/Master3th/Optimization/optimization-tools/Part1/SimplexMethod/plotMatrix.ipynb#ch0000000?line=37'>38</a>     plt.axhline(x2, -5, 5, c=colors[i], label='({0}) x2 * {1} <= {2}'.format(
#      <a href='vscode-notebook-cell:/home/jmichel/Documents/master/Master_James/Master3th/Optimization/optimization-tools/Part1/SimplexMethod/plotMatrix.ipynb#ch0000000?line=38'>39</a>         i+1, A[i][1], b[i][0]))
# ---> <a href='vscode-notebook-cell:/home/jmichel/Documents/master/Master_James/Master3th/Optimization/optimization-tools/Part1/SimplexMethod/plotMatrix.ipynb#ch0000000?line=39'>40</a>     plt.fill_between(
#      <a href='vscode-notebook-cell:/home/jmichel/Documents/master/Master_James/Master3th/Optimization/optimization-tools/Part1/SimplexMethod/plotMatrix.ipynb#ch0000000?line=40'>41</a>         x1, x2, where=x2 <= b[i][0]/A[i][1], interpolate=True, color=colors[i], alpha=0.1)
#      <a href='vscode-notebook-cell:/home/jmichel/Documents/master/Master_James/Master3th/Optimization/optimization-tools/Part1/SimplexMethod/plotMatrix.ipynb#ch0000000?line=42'>43</a> # validate if is a vertical line
#      <a href='vscode-notebook-cell:/home/jmichel/Documents/master/Master_James/Master3th/Optimization/optimization-tools/Part1/SimplexMethod/plotMatrix.ipynb#ch0000000?line=43'>44</a> if A[i][0] != 0 and A[i][1] == 0:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:2555, in fill_between(x, y1, y2, where, interpolate, step, data, **kwargs)
#    2551 @_copy_docstring_and_deprecators(Axes.fill_between)
#    2552 def fill_between(
#    2553         x, y1, y2=0, where=None, interpolate=False, step=None, *,
#    2554         data=None, **kwargs):
# -> 2555     return gca().fill_between(
#    2556         x, y1, y2=y2, where=where, interpolate=interpolate, step=step,
#    2557         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5245, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5243 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5244                  step=None, **kwargs):
# -> 5245     return self._fill_between_x_or_y(
#    5246         "x", x, y1, y2,
#    5247         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5164, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5162     where = np.asarray(where, dtype=bool)
#    5163     if where.size != ind.size:
# -> 5164         raise ValueError(f"where size ({where.size}) does not match "
#    5165                          f"{ind_dir} size ({ind.size})")
#    5166 where = where & ~functools.reduce(
#    5167     np.logical_or, map(np.ma.getmask, [ind, dep1, dep2]))
#    5169 ind, dep1, dep2 = np.broadcast_arrays(
#    5170     np.atleast_1d(ind), dep1, dep2, subok=True)
#
# ValueError: where size (1) does not match x size (100)
